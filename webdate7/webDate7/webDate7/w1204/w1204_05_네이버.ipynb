# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import requests
from bs4 import BeautifulSoup
import time
import os
import random

# %%
url = "https://nid.naver.com/nidlogin.login?mode=form&url=https://www.naver.com/"
service = Service("c:/workspace/webdate7/webDate7/webDate7/chromedriver.exe")
browser = webdriver.Chrome(service=service)
# 1. naver 페이지 열기
browser.get(url)

# input데이터 넣기
input_js = '''
document.getElementById("id").value = "{id}";
document.getElementById("pw").value = "{pw}";
'''.format(id='crsm5207', pw='QQtmfrl7784!')

time.sleep(3)
#time.sleep(random.uniform(1, 3))
# naver에서 elem 찾기해서 데이터 입력시 차단
# 자바스크립트로 사용해서 데이터 입력
browser.execute_script(input_js)
time.sleep(3)
browser.find_element(By.ID,"log.login").click()

# %%
# 광고알림창 닫기 버튼
elem = browser.find_element(By.XPATH,'//*[@id="new.dontsave"]')
time.sleep(1)
elem.click()

# %%
browser.find_element(By.CLASS_NAME,"link_service").click()
time.sleep(3)

# %%
# 탭 이동
browser.switch_to.window(browser.window_handles[1])

# %%
browser.find_element(By.XPATH,'//*[@id="root"]/div/nav/div/div[1]/div[2]/a[1]').click()
time.sleep(3)

# %%
to_input = browser.find_element(By.ID, "recipient_input_element")
to_input.send_keys("soduwkma@naver.com")
time.sleep(1)

to_input.send_keys(Keys.ENTER)

# %%
title_input = browser.find_element(By.ID, "subject_title")

title_input.send_keys("안녕하세요 엔지니어7기 이슬기입니다.")
time.sleep(1)

# %%
iframe = WebDriverWait(browser, 10).until(
    EC.presence_of_element_located((By.CSS_SELECTOR, "iframe[tabindex='5']"))
)

browser.switch_to.frame(iframe)

time.sleep(1)

body_area = WebDriverWait(browser, 10).until(
    EC.presence_of_element_located(
        (By.CSS_SELECTOR, "div.workseditor-content[contenteditable='true']")
    )
)

body_area.click()
body_area.send_keys("89년생 이슬기\n서울 관악구 신림동 거주\n010-4672-7784\n잘 부탁드립니다.")
time.sleep(1)

browser.switch_to.default_content()

# %%
browser.find_element(By.CSS_SELECTOR, "button.button_write_task").click()
