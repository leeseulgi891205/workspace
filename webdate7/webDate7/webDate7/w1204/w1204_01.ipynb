# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
import time
import os

# %%
browser=webdriver.Chrome()
url="http://www.naver.com"
# 1.url 페이지 열기(네이버)
browser.get(url)
# 2.새페이지 열기
browser.get("http://www.daum.net")
# 3.페이지 조작
browser.forward()#다음페이지
browser.back()#이전페이지
# 4.네이버login클릭
browser.find_element(By.CLASS_NAME,'MyView-module__link_login___HpHMW').click()
# 5.아이디
elem=browser.find_element(By.ID,"id")# 선택
elem.click()# 클릭
elem.send_keys('crsm5207')# 입력
# 6.비밀번호
elem=browser.find_element(By.ID,"pw")# 선택
elem.click()# 클릭
elem.send_keys('QQskdlem11!')# 입력
browser.find_element(By.ID,'log.login')

# %%
url = "https://nid.naver.com/nidlogin.login?mode=form&url=https://www.naver.com/"
